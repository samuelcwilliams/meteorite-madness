# %% [markdown]
# # Data Anaysis with Python
# One important step when starting a new project is picking your tools. For the initial analysis, I plan to keep it simple by using the following tools:
# * `pandas`: Used to create Dataframes to manipulate the data easily
# * `numpy`: Used to create arrays to easily and quickly perform operations on specific columns
# * `matplotlib`: Used to create simple visualizations to get a feel for the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# The lines are more of a personal preference rather than a tool.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Here I start by reading in my dataset from a `.csv` file. I then used `df.head()` to verify that the data was properly loaded.

# %%
df = pd.read_csv("Meteorite_Landings.csv")
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    year  latitude  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#    longitude           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %% [markdown]
# ### Light Data Wrangling

# %% [markdown]
# The first question that comes to mind about this dataset is how the data is spread over the years. My intuition tells me that there will be far less observations as the years go back, because older meteorites are generally discovered, rather than observed.
#
# Initially, I created a dataframe from the output of the `value_counts` function, which automatically counts the occurences of each value in a given column. However, this didn't deliver quite what I was looking for, `year` column served as the index rather than as an accessible column. However, this can be avoided by specifically referencing `counts.index` and `counts.values` as columns while creating the `occ` dataframe.

# %%
counts = df['year'].value_counts()
occ = pd.DataFrame({'year': counts.index, 'impacts': counts.values})
occ
# Out:
#        year  impacts
# 0    2003.0     3323
# 1    1979.0     3046
# 2    1998.0     2697
# 3    2006.0     2456
# 4    1988.0     2296
# ..      ...      ...
# 260  1741.0        1
# 261  1519.0        1
# 262  1671.0        1
# 263  1779.0        1
# 264  1792.0        1
#
# [265 rows x 2 columns]

# %% [markdown]
# Using the `counts` dataframe, we should be able to easily visualize the impacts over time:

# %%
# need to modify this so that it's easier to read. also would be nice to have a plot that goes from 1800 to 2020 so
# that more detail can be seen.
plt.bar(occ['year'], occ['impacts'])
plt.xlabel('Year');
plt.ylabel('Impacts');
plt.title('Meteorite Impacts per Year');

# %%
# want to make a couple of pivot tables to summarize the data at the beginning. once i've done that, i'm going to
# start looking at specific meteorite characteristics and working on using scikitlearn to make some models
pivot = df.pivot_table(index =['year'], values =['mass (g)'], 
                       aggfunc ={'median', 'mean', 'max'})
pivot
# Out:
#           mass (g)
#                max          mean       median
# year
# 860.0        472.0  4.720000e+02       472.00
# 1399.0    107000.0  1.070000e+05    107000.00
# 1490.0       103.3  1.033000e+02       103.30
# 1491.0    127000.0  1.270000e+05    127000.00
# 1575.0  50000000.0  5.000000e+07  50000000.00
# ...            ...           ...          ...
# 2010.0    100000.0  6.335639e+02        55.70
# 2011.0    115777.0  1.070850e+03       119.00
# 2012.0     18000.0  9.923832e+02       300.65
# 2013.0    100000.0  9.471636e+03       459.00
# 2101.0        55.0  5.500000e+01        55.00
#
# [253 rows x 3 columns]

# %%
df['recclass'].value_counts()
# what are those rare kinds of meteorites? also, how can I
# Out:
# L6         8285
# H5         7142
# L5         4796
# H6         4528
# H4         4211
#            ...
# EL7           1
# CH/CBb        1
# H/L~4         1
# LL3.7-6       1
# L/LL          1
# Name: recclass, Length: 466, dtype: int64
